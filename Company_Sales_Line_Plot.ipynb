# %% [markdown]
# <a href="https://colab.research.google.com/github/LizzyOrji123/-about-hook/blob/main/Company_Sales_Line_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir())  # This will show all files in your Colab workspace
# Out:
# ['.config', 'sample_data']

# %%
# !pip install matplotlib pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
print(os.listdir())
# Out:
# ['.config', '.ipynb_checkpoints', 'company_sales_data.csv', 'sample_data']

# %%
data = pd.read_csv("company_sales_data.csv")

# %%
months = data["month_number"]
total_profit = data["total_profit"]

# %%
plt.figure(figsize=(10, 5))
plt.plot(months, total_profit, marker='o', linestyle='-', color='b', label="Total Profit")
plt.xlabel("Month Number")
plt.ylabel("Profit ($)")
plt.title("Total Profit Per Month")
plt.legend()
plt.grid(True)
plt.show()
